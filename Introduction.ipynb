# %% [markdown]
# ### Welcome to Insights into Python-III
# ### "Python for Machine Learning"

# %%
from IPython.display import Image
PATH = "/home/sonal/Downloads/"
Image(filename = PATH + "sonal_link.jpg", width=400, height=30)

# %% [markdown]
# ### Agenda
#
# * [Introduction](#Introduction)
#     * [AI-ML-DL](#AI-ML-DL)
#     * [Types of ML tech.](#Types_of_ML_tech.)
#         * [Supervised Learning](#Supervised_Learning)
#         * [Python libraries](#Python_libraries)
# * [Linear Reggression](#Linear_Regressiion)
#     * [using Scikit-learn](#using_Scikit-learn)
#     * [using Neural Network, Keras](#using_Neural_Network_Keras)
# * [ML best practices to remember](#ML_best_practices_to_remember)
#    * [Train_Test_split](#Train_Test_split)
#    * [Bias-Variance-Tradeoff](#Bias_Variance_Tradeoff)
#    * [Overfitting_Unerfitting](#OVerfitting_Underfitting)
# * [Application on Climate data](#Application_on_Climate_data)

# %% [markdown]
# ### Learning = Representation + Evaluation + Optimization

# %% [markdown]
# ### Machine learning means learning from data
# #### - provides data-driven decisions based only on the input data (features, relationship between data)

# %%
from IPython.display import Image
PATH = "/home/sonal/Downloads/"
Image(filename = PATH + "ai-ml-dl.png", width=500, height=500)

# %%
from IPython.display import Image
PATH = "/home/sonal/Downloads/"
Image(filename = PATH + "mltech.png", width=500, height=500)

# %%
from IPython.display import Image
PATH = "/home/sonal/Downloads/"
Image(filename = PATH + "sl.jpg", width=600, height=20)

# %%
from IPython.display import Image
PATH = "/home/sonal/Downloads/"
Image(filename = PATH + "cr.png", width=1000, height=1000)

# %% [markdown]
# ### Deep learning- based on artificial neural networks
# #### -provides nonlinear activation functions
# ##### - cannot be linear because neural networks with a linear activation function are effective only one layer deep, regardless of how complex their architecture is. ... Therefore, nonlinear functions must be continuous and differentiable between this range

# %% [markdown]
# ![NN](https://nanonets.com/blog/content/images/2019/12/Blog-Model2.gif "NN")

# %%
from IPython.display import Image
PATH = "/home/sonal/Downloads/"
Image(filename = PATH + "af.png", width=500, height=500)

# %%
from IPython.display import HTML

HTML('''<script> $('div .input').hide()''')
# Out:
# <script> $('div .input').hide()
