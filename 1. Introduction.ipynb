# %% [markdown]
# ### Welcome to Insights into Python-III
# ### "Python for Machine Learning"

# %% [markdown]
# #### Sonal Rami:
# * MSc in Computer Science & Engineering
# * doing PhD in Physical Oceanography + Machine Learning @ AWI, Uni_Bremen, MarDATA

# %% [markdown]
# ### Agenda
#
# * [Introduction](#Introduction)
#     * [AI-ML-DL](#AI-ML-DL)
#     * [Types of ML tech.](#Types_of_ML_tech.)
#         * [Supervised Learning](#Supervised_Learning)
#         * [Python essential libraries](#Python_libraries)
# * [Linear and Nonlinear Reggression](#Linear_and_Nonlinear_Regressiion)
#     * [using Scikit-learn](#using_Scikit-learn)
#     * [using Neural Network, Keras](#using_Neural_Network_Keras)
# * [ML best practices to remember](#ML_best_practices_to_remember)
#    * [Train_Test_split](#Train_Test_split)
#    * [Overfitting_Unerfitting](#OVerfitting_Underfitting)
#    * [Bias-Variance-Tradeoff](#Bias-Variance-Tradeoff)
# * [Experiment_on_real_data](#Experiment_on_real_data)
# * [Closing_remarks](#Closing_remarks)

# %% [markdown]
# ### Learning = Representation + Evaluation + Optimization

# %% [markdown]
# ### Machine learning:
# * Learning from data
# * Provides data-driven decisions based only on the input data (features, relationship between data)

# %% [markdown]
# ![ai-ml-dl.png](attachment:ai-ml-dl.png)

# %% [markdown]
# ### Types of ML techniques:

# %% [markdown]
# ![sl.jpg](attachment:sl.jpg) | ![cr.png](attachment:cr.png)

# %% [markdown]
# ### Deep learning:
# * Based on artificial neural networks
# * Provides nonlinear activation functions
# * AF cannot be linear because neural networks with a linear activation function are effective only one layer deep, regardless of how complex their architecture is.
#    * Therefore, nonlinear functions must be continuous and differentiable between given range

# %% [markdown]
# ### Artificial Neural Network:

# %% [markdown]
# ![NN](https://nanonets.com/blog/content/images/2019/12/Blog-Model2.gif "NN")

# %% [markdown]
# ### Types of Activation Functions:

# %% [markdown]
# ![af.png](attachment:af.png)

# %% [markdown]
# ### Python Ecosystem for Machine Learning:
# * The availability of libraries and open source tools make it ideal choice for developing ML models
# * Essential libraries:

# %% [markdown]
# ![ecosystem.png](attachment:ecosystem.png)
